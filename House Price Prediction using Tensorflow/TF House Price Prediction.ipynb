# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('datasets/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# /home/vitesh_18/venv/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.countplot(df['bedrooms'])
# Out:
# /home/vitesh_18/venv/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(y='sqft_living',x='price',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y='price',x='bedrooms',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
len(df)*0.01
# Out:
# 215.97

# %%
data_with_no_top_10=df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(y='lat',x='long',data=data_with_no_top_10,hue='price',palette='RdYlGn',alpha=0.2,edgecolor=None) 
#some houses which have seaview or near water are more expensive and we can see that with these green points.
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df=df.drop('id',axis=1)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['year']=df['date'].apply(lambda date:date.year)
df['month']=df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sns.boxplot(x='year',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df['yr_renovated'].value_counts() # this feature can be used as it is because we can see latest the year will have more price than the oldest one so no need to do feature engineering
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df=df.drop('zipcode',axis=1) #we can also make this a categorize feature with expensive zipcodes vs less expensive but for that we should have domain knowledge
#and creating dummy variables will be so much as we have 70 diff zipcodes so here we can drop this feature.

# %%
df=df.drop('date',axis=1)

# %%
X=df.drop('price',axis=1).values
y=df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=101,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.fit_transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

model.add(Dense(19,activation='relu'))#typically we use no of neurons = no of features
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu')) 
model.add(Dense(19,activation='relu'))

model.add(Dense(1)) #final layer

# %%
model.compile(optimizer='adam',loss='mse') #adam is the mostly used and effective optimizer

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),epochs=400,batch_size=128) #typically batch_size is in power of 2
#validation data will not effect the values of weights and biases, this is only used for testing purpose
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 3ms/step - loss: 432618225664.0000 - val_loss: 418859057152.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 417790421401.6000 - val_loss: 414347493376.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 420185183300.2667 - val_loss: 377743704064.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 364035121425.0667 - val_loss: 258383233024.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 215599846195.2000 - val_loss: 123090001920.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 101538047522.1333 - val_loss: 96218701824.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 102472796979.2000 - val_loss: 94310686720.0000
# Epoch 8/400
# ...

# %%
pred_df=pd.DataFrame(model.history.history)

# %%
pred_df.head()
# Out:
#            loss      val_loss
# 0  4.302271e+11  4.188591e+11
# 1  4.287601e+11  4.143475e+11
# 2  4.113109e+11  3.777437e+11
# 3  3.317970e+11  2.583832e+11
# 4  1.829180e+11  1.230900e+11

# %%
 pred_df.plot() #as we can see both val_loss and loss are decreasing that means there is no overfitting and we can also continue our training to get more better results
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
y_pred=model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 184987.0332756771

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 112166.86798502604

# %%
explained_variance_score(y_test,y_pred)
# Out:
# 0.7789501306371434

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=y_test,y=y_pred)
plt.plot(y_test,y_test,'r')

# %%
n_house=df.drop('price',axis=1).iloc[0]

# %%
n_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  2.01400e+03,  1.00000e+01])

# %%
n_house=scaler.transform(n_house.values.reshape(-1,19))

# %%
n_house
# Out:
# array([[0.0625    , 0.06666667, 0.05792683, 0.00516884, 0.        ,
#         0.        , 0.        , 0.5       , 0.33333333, 0.08453838,
#         0.        , 0.47826087, 0.        , 0.56720299, 0.215     ,
#         0.13926499, 0.00574235, 0.        , 0.81818182]])

# %%
model.predict(n_house)
# Out:
# array([[246138.11]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
