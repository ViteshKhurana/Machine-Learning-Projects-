# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('datasets/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
corr=df.corr()['benign_0__mal_1'].sort_values()
corr
# Out:
# worst concave points      -0.793566
# worst perimeter           -0.782914
# mean concave points       -0.776614
# worst radius              -0.776454
# mean perimeter            -0.742636
# worst area                -0.733825
# mean radius               -0.730029
# mean area                 -0.708984
# mean concavity            -0.696360
# worst concavity           -0.659610
# mean compactness          -0.596534
# worst compactness         -0.590998
# radius error              -0.567134
# perimeter error           -0.556141
# area error                -0.548236
# worst texture             -0.456903
# worst smoothness          -0.421465
# worst symmetry            -0.416294
# mean texture              -0.415185
# concave points error      -0.408042
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# ...

# %%
plt.figure(figsize=(10,6))
corr[:-1].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X=df.drop('benign_0__mal_1',axis=1).values
y=df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=101,test_size=0.25)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model1=Sequential()

model1.add(Dense(30,activation='relu'))

model1.add(Dense(15,activation='relu'))

model1.add(Dense(1,activation='sigmoid')) #we use sigmoid as our activation function in last layer because our problem is binary classification and this function will output between 0 and 1

model1.compile(optimizer='adam',loss='binary_crossentropy') #for binary classification task

# %%
model1.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 3s 150ms/step - loss: 0.7158 - val_loss: 0.6627
# Epoch 2/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6564 - val_loss: 0.6266
# Epoch 3/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6197 - val_loss: 0.5900
# Epoch 4/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5814 - val_loss: 0.5507
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5486 - val_loss: 0.5091
# Epoch 6/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5126 - val_loss: 0.4657
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4505 - val_loss: 0.4208
# Epoch 8/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4153 - val_loss: 0.3784
# Epoch 9/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3862 - val_loss: 0.3394
# Epoch 10/600
# ...

# %%
model_history1=pd.DataFrame(model1.history.history)
model_history1
# Out:
#          loss  val_loss
# 0    0.703114  0.662701
# 1    0.647844  0.626570
# 2    0.612200  0.589966
# 3    0.574580  0.550726
# 4    0.535317  0.509064
# ..        ...       ...
# 595  0.016962  0.209276
# 596  0.017917  0.189766
# 597  0.017581  0.205754
# 598  0.016860  0.188794
# 599  0.018058  0.208187
#
# [600 rows x 2 columns]

# %%
model_history1.plot() #here we can see that the val_loss is increasing after a certain point. This is the condition of overfitting
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y_pred1=model1.predict_classes(X_test)
# Out:
# /home/vitesh_18/venv/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(classification_report(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        55
#            1       0.98      0.92      0.95        88
#
#     accuracy                           0.94       143
#    macro avg       0.93      0.94      0.93       143
# weighted avg       0.94      0.94      0.94       143
#
# [[53  2]
#  [ 7 81]]

# %% [markdown]
# # Early stopping for improving model

# %%
model2=Sequential()

model2.add(Dense(30,activation='relu'))

model2.add(Dense(15,activation='relu'))

model2.add(Dense(1,activation='sigmoid')) 

model2.compile(optimizer='adam',loss='binary_crossentropy')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stopping=EarlyStopping(monitor='val_loss',patience=25,mode='min',verbose=1) #patience is the no of epochs for which model
#will continue training after an earlystopping is occured. This will help us to check if the early stopping is because of 
#noise or model is overfitting after that point.

# %%
model2.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6683 - val_loss: 0.6536
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6451 - val_loss: 0.6260
# Epoch 3/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6129 - val_loss: 0.5899
# Epoch 4/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5731 - val_loss: 0.5465
# Epoch 5/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5374 - val_loss: 0.4972
# Epoch 6/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4844 - val_loss: 0.4417
# Epoch 7/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4276 - val_loss: 0.3891
# Epoch 8/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3757 - val_loss: 0.3384
# Epoch 9/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3526 - val_loss: 0.2978
# Epoch 10/600
# ...

# %%
model_history2=pd.DataFrame(model2.history.history)

# %%
model_history2.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred2=model2.predict_classes(X_test)
# Out:
# /home/vitesh_18/venv/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(classification_report(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        55
#            1       0.99      0.97      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143
#
# [[54  1]
#  [ 3 85]]

# %%
model3=Sequential()

model3.add(Dense(30,activation='relu')) #dropout will randomly deactivate some of the neurons in the layer
model3.add(Dropout(0.5)) #this will take rate between 0 to 1 that indicates what percentage of neurons we want to deactivate

model3.add(Dense(15,activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(1,activation='sigmoid')) 

model3.compile(optimizer='adam',loss='binary_crossentropy')

# %%
model3.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 12ms/step - loss: 0.7201 - val_loss: 0.6918
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6971 - val_loss: 0.6796
# Epoch 3/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6753 - val_loss: 0.6632
# Epoch 4/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6758 - val_loss: 0.6450
# Epoch 5/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6465 - val_loss: 0.6232
# Epoch 6/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6378 - val_loss: 0.6017
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6188 - val_loss: 0.5797
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6017 - val_loss: 0.5557
# Epoch 9/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5646 - val_loss: 0.5274
# Epoch 10/600
# ...

# %%
model_history3=pd.DataFrame(model3.history.history)

# %%
model_history3.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred3=model3.predict_classes(X_test)
# Out:
# /home/vitesh_18/venv/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(classification_report(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.99      0.98      0.98        88
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.98      0.98       143
# weighted avg       0.98      0.98      0.98       143
#
# [[54  1]
#  [ 2 86]]
